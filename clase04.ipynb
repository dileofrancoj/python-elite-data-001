# %% [markdown]
# ### Repaso de funciones
#
# Una función es un bloque de código reutilizable diseñado para realizar una tarea específica. Las funciones son fundamentales en la programación porque permiten organizar el código de manera lógica, mejorar su legibilidad y evitar la repetición.
#
# Tipos de funciones:
#
# - Sin argumentos (con o sin retorno de valor)
# - Con argumentos (con o sin retorno de valor)
#
# El return en las funciones sirve para comunicar el resultado al "mundo exterior"
#
# 1) Contar elementos mayores a cierto valor
# 2) Unir 2 listas sin repetir elementos

# %%
lista = ["fabi", "guille","fran","pao"]
# Dentro de la lista hay muchos elementos
# Quiero verificar si en la lista está el alumno fran
print(lista)
# Out:
# ['fabi', 'guille', 'fran', 'pao']

# %%
for elemento in lista:
    if elemento == "Fran":
        print("Fran está en la lista de alumnos")

# %%
# Unir 2 listas sin repetir elementos

# %%
list1 = [1,5,9]
list2 = [2,6,9,8]
list1 + list2
# Out:
# [1, 5, 9, 2, 6, 9, 8]

# %%
# una lista, una tupla, diccionarios, pasa por referencia
def join_lists_without_duplicates(l1, l2):
    result = []
    for item in l1 + l2:
        if item not in result: # if 9 not in [1,5,9,2,6]
            result.append(item)
        else:
            print("Elemento duplicado ->", item)
    # print(result)
    # comunicar la lista final al exterior de la función
    return result

# %%
list_without_duplicates = join_lists_without_duplicates(list1, list2)
# Out:
# Elemento duplicado -> 9

# %%
print(list_without_duplicates)
# Out:
# [1, 5, 9, 2, 6, 8]

# %%
list_dot_two = []
for item in list_without_duplicates:
    list_dot_two.append(item*2)

print(list_dot_two)
# Out:
# [2, 10, 18, 4, 12, 16]

# %% [markdown]
# ### Pandas vs Polars
#
# Son librerias de python que se utilizan para el manejo y el análisis de datos. Características:
# - Leectura y escritura en formato (CSV, EXCEL, SQL, TXT, JSON, XML)
# - Ofrece métodos para ordenar, dividir y combinar conjuntos de datos
# - Permite trabajar con series temporales
#
# Los principales tipos de datos:
# - Series
# - Dataframes
# - Paneles (tensores) (no lo vamos a usar seguido)
#
#
# Una serie tiene la forma:
# serie = [1,2,3,4,5,6]
#
# Las series no son listas convencionales sino que por abajo funcionan con numpy
#
# dataframes = [[1,2,3],[4,5,6]]

# %%
# pip | conda

# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install polars
# pip install scipy

# %%
l1 = [1,2,3]
l1.append(4)

# %%
# alias
import pandas as pd
import polars as po

# %%
# pd.read_csv(...) es una función que recibe n parámetros posicionales (nombrados)
# retorna un objeto de tipo serie / dataframe / panel

# %%
df = pd.read_csv("./stroke.csv")

# %%
df2 = po.read_csv("./stroke.csv", ignore_errors=True)

# %%
type(df2)
# Out:
# polars.dataframe.frame.DataFrame

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# ### Algunos métodos y propiedades útiles
#
# df.head()
#
# **df.head(x)** es un metodo del objeto Dataframe que devuelve los primeros x de elementos del dataframe
#
# **df.tail(x)** es un método del objeto df que devuelve los ultimos x elementos del dataframe
#
# **df.shape**: Nos devuelve una tupla (m, n) siendo m la cantidad de registros y n la cantidad de features
#
# **df.dtypes**: data type de cada una de las columnas
#
# **df.info()**: Información general del dataframe
#
# **df.describe()** Información estadística básica del dataframe
#
# **df.isnull().sum()** cuenta la cantidad de valores nulos del dataframe
#
# **df['bmi'].isnull().sum()** cuenta la cantidad de nulos de la serie bmi

# %%
# df.shape nos devuelve una tupla con la cantidad de registros, la cantidad de capos (features)
# las listas son elementos mutables list.append("lo que sea")
df.shape
# Out:
# (5110, 12)

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.tail(10)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5100  68398    Male  82.0             1              0          Yes
# 5101  36901  Female  45.0             0              0          Yes
# 5102  45010  Female  57.0             0              0          Yes
# 5103  22127  Female  18.0             0              0           No
# 5104  14180  Female  13.0             0              0           No
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5100  Self-employed          Rural              71.97  28.3     never smoked
# ...

# %%
df.info() # info general del dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe() # info estadísticamente relevante
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %% [markdown]
# - Calidad de los datos (exploración)
# - Cantidad de datos
# - Hipotesis a la hora de hacer mi EDA (Exploratory data analysis)

# %% [markdown]
# ### Operaciones sobre nuestros datos

# %%
print(df["age"])
print("*****")
print(df[["age","gender","bmi"]])
# Out:
# 0       67.0
# 1       61.0
# 2       80.0
# 3       49.0
# 4       79.0
#         ...
# 5105    80.0
# 5106    81.0
# 5107    35.0
# 5108    51.0
# 5109    44.0
# Name: age, Length: 5110, dtype: float64
# *****
#        age  gender   bmi
# 0     67.0    Male  36.6
# 1     61.0  Female   NaN
# 2     80.0    Male  32.5
# 3     49.0  Female  34.4
# 4     79.0  Female  24.0
# ...    ...     ...   ...
# 5105  80.0  Female   NaN
# 5106  81.0  Female  40.0
# 5107  35.0  Female  30.6
# 5108  51.0    Male  25.6
# 5109  44.0  Female  26.2
#
# [5110 rows x 3 columns]

# %%
# quiero filtrar a aquellas personas +75 años
df_elderly = df[df["age"] >= 75]

# %%
df_elderly.head(2)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 2  31112    Male  80.0             0              1          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 2        Private          Rural             105.92  32.5   never smoked
# 4  Self-employed          Rural             174.12  24.0   never smoked
#
#    stroke
# 2       1
# 4       1

# %%
df_elderly_with_strokes = df[(df["age"] >= 75) & (df['stroke'] == 1) & (df["Residence_type"] == "Rural")]

# %%
df_elderly_with_strokes.head()
# Out:
#        id  gender   age  hypertension  heart_disease ever_married  \
# 2   31112    Male  80.0             0              1          Yes
# 4    1665  Female  79.0             1              0          Yes
# 10  12109  Female  81.0             1              0          Yes
# 23  64778    Male  82.0             0              1          Yes
# 25  70822    Male  80.0             0              0          Yes
#
#         work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 2         Private          Rural             105.92  32.5   never smoked
# 4   Self-employed          Rural             174.12  24.0   never smoked
# 10        Private          Rural              80.43  29.7   never smoked
# 23        Private          Rural             208.30  32.5        Unknown
# 25  Self-employed          Rural             104.12  23.5   never smoked
#
#     stroke
# 2        1
# 4        1
# 10       1
# 23       1
# 25       1

# %%
# Contar valores y sumar valores nulos

# %%
# .count() cuenta los registros no nulos de un dataframe / serie
df['bmi'].count() # .count() cuenta los elementos no-nulos no-NaN
# Out:
# 4909

# %%
# Cuenta todos los registros de la columna 'bmi'
len(df['bmi'])
# Out:
# 5110

# %%
# df.isnull() devuelve un dataframe de booleanos (True para nulos), False para no nulos

# %%
# Quiero obtener la cantidad de nulos en todo el dataframe
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Quiero obtener la cantidad de valores nulos de la columna bmi
df['bmi'].isnull().sum()
# Out:
# 201

# %% [markdown]
# # Imputación de datos
#
# Sustituir datos faltantes en un conjunto de datos por valores estimados.
#
# ### Valor constante
#
# Reemplazo un valor NULL / NaN / NA / "Unknown" por un valor constante
#
# ### Reemplazar por la media / mediana / moda
# - Media: Cuando tenemos datos continuos y NO TENEMOS OUTLIERS
# - Mediana: Cuando el dato es continuo y hay outliers
# - Moda: El valor que más se repite en datos categóricos
#
# ### Imputación basada en estadística
#
# Usar agrupaciones / estratos dentro de nuestra muestra. Calcular la media, mediana o moda de estratos relevantes.
# XEJ: Calcular la media del BMI para distintos grupos (menores a 20, entre 20 y 40 años, mayores a 40) y en función de eso asignar el valor a los datos faltantes.

# %%
df.groupby('gender')['avg_glucose_level'].mean()
# Out:
# gender
# Female    104.057809
# Male      109.088520
# Other     143.330000
# Name: avg_glucose_level, dtype: float64

# %%
df[df['stroke'] == 1]
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 0     9046    Male  67.0             0              1          Yes
# 1    51676  Female  61.0             0              0          Yes
# 2    31112    Male  80.0             0              1          Yes
# 3    60182  Female  49.0             0              0          Yes
# 4     1665  Female  79.0             1              0          Yes
# ..     ...     ...   ...           ...            ...          ...
# 244  17739    Male  57.0             0              0          Yes
# 245  49669  Female  14.0             0              0           No
# 246  27153  Female  75.0             0              0          Yes
# 247  34060    Male  71.0             1              0          Yes
# 248  43424  Female  78.0             0              0          Yes
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0          Private          Urban             228.69  36.6  formerly smoked
# ...
